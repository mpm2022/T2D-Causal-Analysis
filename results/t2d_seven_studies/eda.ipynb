# %%
import pandas as pd
import numpy as np

# %%
otu_table = pd.read_csv("../../../Causal-Discovery-for-Biomedical-Applications/data/sam-t2d/otu_table.csv")
otu_table
# Out:
#       Unnamed: 0  \
# 0    SRR16113010
# 1    SRR16112701
# 2     SRR9679959
# 3     ERR9763111
# 4     ERR9763104
# ..           ...
# 806  SRR16112703
# 807  SRR16112937
# 808  SRR16112717
# 809  SRR16112648
# 810  SRR16112790
#
#      d__Bacteria;p__Bacillota_A_368345;c__Clostridia_258483;o__Lachnospirales;f__Lachnospiraceae;__  \
# 0                                            13.057867
# 1                                             6.788602
# 2                                             2.311604
# 3                                             8.936595
# 4                                             6.218302
# ..                                                 ...
# 806                                          31.017103
# 807                                          10.750951
# 808                                           8.312378
# 809                                          12.971435
# 810                                          29.808956
#
# ...

# %%
metadata = pd.read_csv("../../../Causal-Discovery-for-Biomedical-Applications/data/sam-t2d/metadata.csv")
metadata
# Out:
#        sample-id  t2d  study  region_num
# 0     SRR9679957    1      1           2
# 1     SRR9679958    0      1           2
# 2     SRR9679959    0      1           2
# 3     SRR9679960    1      1           2
# 4     SRR9679961    0      1           2
# ..           ...  ...    ...         ...
# 806  SRR12929838    1      7           3
# 807  SRR12929837    1      7           3
# 808  SRR12929836    1      7           3
# 809  SRR12929835    1      7           3
# 810  SRR12929834    1      7           3
#
# [811 rows x 4 columns]

# %%
filtered_otu_table = pd.read_csv("../../../Causal-Discovery-for-Biomedical-Applications/data/sam-t2d/filtered_otu_table_norm.csv")
filtered_otu_table
# Out:
#       Unnamed: 0  \
# 0    SRR16113010
# 1    SRR16112701
# 2     SRR9679959
# 3     ERR9763111
# 4     ERR9763104
# ..           ...
# 806  SRR16112703
# 807  SRR16112937
# 808  SRR16112717
# 809  SRR16112648
# 810  SRR16112790
#
#      d__Bacteria;p__Bacillota_A_368345;c__Clostridia_258483;o__Lachnospirales;f__Lachnospiraceae;__  \
# 0                                            13.057867
# 1                                             6.788602
# 2                                             2.311604
# 3                                             8.936595
# 4                                             6.218302
# ..                                                 ...
# 806                                          31.017103
# 807                                          10.750951
# 808                                           8.312378
# 809                                          12.971435
# 810                                          29.808956
#
# ...

# %%
healthy = pd.read_csv("../../../Causal-Discovery-for-Biomedical-Applications/data/sam-t2d/No_norm.csv")
healthy
# Out:
#       Unnamed: 0  \
# 0     SRR9679958
# 1     SRR9679959
# 2     SRR9679961
# 3     SRR9679966
# 4     SRR9679968
# ..           ...
# 279  SRR12929831
# 280  SRR12929842
# 281  SRR12929841
# 282  SRR12929840
# 283  SRR12929839
#
#      d__Bacteria;p__Bacillota_A_368345;c__Clostridia_258483;o__Lachnospirales;f__Lachnospiraceae;__  \
# 0                                             0.944311
# 1                                             2.311604
# 2                                             1.720138
# 3                                             3.390724
# 4                                             3.072786
# ..                                                 ...
# 279                                          22.832103
# 280                                           9.282250
# 281                                          14.106792
# 282                                          16.100389
# 283                                           4.177145
#
# ...

# %%
diseased = pd.read_csv("../../../Causal-Discovery-for-Biomedical-Applications/data/sam-t2d/Yes_norm.csv")
diseased
# Out:
#       Unnamed: 0  \
# 0     SRR9679957
# 1     SRR9679960
# 2     SRR9679962
# 3     SRR9679963
# 4     SRR9679964
# ..           ...
# 522  SRR12929838
# 523  SRR12929837
# 524  SRR12929836
# 525  SRR12929835
# 526  SRR12929834
#
#      d__Bacteria;p__Bacillota_A_368345;c__Clostridia_258483;o__Lachnospirales;f__Lachnospiraceae;__  \
# 0                                             8.851514
# 1                                             6.713501
# 2                                             4.326047
# 3                                             5.187431
# 4                                             7.509631
# ..                                                 ...
# 522                                           2.721858
# 523                                           2.322880
# 524                                           2.175658
# 525                                          15.528298
# 526                                           8.346469
#
# ...

# %%
glasso_healthy = pd.read_csv("../../../Causal-Discovery-for-Biomedical-Applications/data/sam-t2d/glasso_No_norm.csv")
glasso_healthy
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# 0    0.015516  0.000000  0.002444  0.000000  0.002674 -0.004515  0.000000
# 1    0.000000  0.397002  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    0.002444  0.000000  0.009096  0.000000  0.001613  0.000141 -0.000203
# 3    0.000000  0.000000  0.000000  0.391773  0.000000  0.000000  0.000000
# 4    0.002674  0.000000  0.001613  0.000000  0.039121  0.001192  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 251  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 252  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 253  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 254  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 255  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#            V8        V9       V10  ...  V247  V248  V249  V250  V251  \
# ...

# %%
(glasso_healthy != 0).sum().sum() - 256
# Out:
# np.int64(224)

# %%
glasso_diseased = pd.read_csv("../../../Causal-Discovery-for-Biomedical-Applications/data/sam-t2d/glasso_Yes_norm.csv")
glasso_diseased
# Out:
#            V1        V2        V3        V4        V5        V6   V7   V8  \
# 0    0.015264  0.000000  0.001505  0.000000  0.000592 -0.000926  0.0  0.0
# 1    0.000000  0.308527  0.000000  0.000000  0.000000  0.000000  0.0  0.0
# 2    0.001505  0.000000  0.010173  0.000000  0.001482  0.000000  0.0  0.0
# 3    0.000000  0.000000  0.000000  0.414126  0.000000  0.000000  0.0  0.0
# 4    0.000592  0.000000  0.001482  0.000000  0.028993  0.001560  0.0  0.0
# ..        ...       ...       ...       ...       ...       ...  ...  ...
# 251  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0
# 252  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0
# 253  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0
# 254  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0
# 255  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0
#
#            V9       V10  ...  V247  V248  V249  V250  V251      V252  \
# ...

# %%
(glasso_diseased != 0).sum().sum() - 256
# Out:
# np.int64(222)
